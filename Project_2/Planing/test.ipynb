# %%
from planning import *

path_points = [[0,0,0],
               [1.18, -0.535, 0.755],
               [2.20, +0.100, 1.200],
               [1.00, +1.500, 1.000],
               [0,0,0]]

planner = MotionPlanner3D(path = path_points,
                          DEBUG = True)

planner.trajectory_setpoints[0:5]
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -3.99220770e-01],
#        [ 2.20259938e-04, -1.03301482e-04,  1.76593112e-04,
#         -4.38733465e-01],
#        [ 1.69954431e-03, -7.98247247e-04,  1.35455335e-03,
#         -4.39475885e-01],
#        [ 5.52922557e-03, -2.60058802e-03,  4.37981464e-03,
#         -4.40173716e-01],
#        [ 1.26265100e-02, -5.94643130e-03,  9.93802735e-03,
#         -4.40816963e-01]])

# %%
cm = 0.01

HOVER_HEIGHT  = 25*cm  

TARGET_POINTS = [[0.0, 0.0, HOVER_HEIGHT],
                 [+0.3, -0.3, HOVER_HEIGHT],
                 [+0.8, 0.0, HOVER_HEIGHT],
                 [+0.3, +0.3, HOVER_HEIGHT],
                 [0.0, 0.0, HOVER_HEIGHT]
                ]   

Drone_Planner = MotionPlanner3D(path = TARGET_POINTS,
                                DEBUG= True,)
