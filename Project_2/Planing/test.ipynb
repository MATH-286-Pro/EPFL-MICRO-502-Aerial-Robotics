# %%
from planning import *

# %%
path_points = [[0,0,0],
               [1.18, -0.535, 0.755],
               [2.20, +0.100, 1.200],
               [1.00, +1.500, 1.000],
               [0,0,0]]

planner = MotionPlanner3D(path = path_points,
                          DEBUG = True)
