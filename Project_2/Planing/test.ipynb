# %%
from planning import *

path_points = [[0,0,0],
               [1.18, -0.535, 0.755],
               [2.20, +0.100, 1.200],
               [1.00, +1.500, 1.000],
               [0,0,0]]

planner = MotionPlanner3D(waypoints = path_points,
                          DEBUG = True)

planner.trajectory_setpoints[0:5]
# Out:
# array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         -2.74237188e+00],
#        [ 2.20259938e-04, -1.03301482e-04,  1.76593112e-04,
#         -4.38733465e-01],
#        [ 1.69954431e-03, -7.98247247e-04,  1.35455335e-03,
#         -4.39475885e-01],
#        [ 5.52922557e-03, -2.60058802e-03,  4.37981464e-03,
#         -4.40173716e-01],
#        [ 1.26265100e-02, -5.94643130e-03,  9.93802735e-03,
#         -4.40816963e-01]])

# %%
import os
import sys

# 将上一级目录添加到 sys.path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

import TOOLS
import pandas as pd


cm = 0.01
HOVER_HEIGHT  = 25*cm  
Trajectory = TOOLS.Trajectory_Class('../../position_records.csv')

from planning import MotionPlanner3D
test_planner = MotionPlanner3D(waypoints = Trajectory.point_list,
                               DEBUG = 0)

print(len(test_planner.trajectory_setpoints))
test_planner.plot_continuous(None, test_planner.waypoints, test_planner.trajectory_setpoints)
test_planner.plot_discrete(None, test_planner.waypoints, test_planner.get_sparse_trajectory(distance=0.5))
test_planner.plot_discrete(None, test_planner.waypoints, test_planner.trajectory_setpoints)
# Out:
# 160

# %%
import os
import sys

# 将上一级目录添加到 sys.path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)
import TOOLS
import pandas as pd
import PLOT

from planning import MotionPlanner3D

cm = 0.01
HOVER_HEIGHT  = 60*cm  
Trajectory = TOOLS.Trajectory_Class('../../position_records.csv',
                                    Hover_Height = HOVER_HEIGHT                                    )
test_planner = MotionPlanner3D(waypoints = Trajectory.point_list,
                               DEBUG = 0)

data_1 = PLOT.get_real_pos_list("../../flight_log_1.csv")
data_2 = PLOT.get_real_pos_list("../../flight_log_2.csv")
data_3 = PLOT.get_real_pos_list("../../flight_log_3.csv")
data_6 = PLOT.get_real_pos_list("../../flight_log_6_OpenLoop.csv")
# PLOT.plot_multiple_flight_logs([data_1, data_2, data_3, test_planner.trajectory_setpoints])
PLOT.plot_multiple_flight_logs([data_6, test_planner.trajectory_setpoints])
